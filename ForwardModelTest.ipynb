# %%
from config import *

# %% [markdown]
# # Measurements

# %%
from Models.Papers import RiedGuachalla2025, Liu2025
importlib.reload(Liu2025)

RG25 = RiedGuachalla2025.Measurements(bin='z_1')
L25 = Liu2025.Measurements(zbin='z1', ACTDR='DR6', dp='dBeta', Beta='fiducial', TCIB='10.7')

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')
axs[0].set(xlabel=r'$\theta$ [arcmin]', ylabel=r'$y$')
axs[1].set(xlabel=r'$\theta$ [arcmin]', ylabel=r'$T_{kSZ} \ [\mu \text{K} \ \text{arcmin}^2]$', yscale='log')

axs[0].errorbar(L25.R, L25.tSZ_data, yerr=L25.tSZ_err, fmt='o', label='Liu 2025', capsize=5)
axs[1].errorbar(RG25.R, RG25.TkSZ_data, yerr=RG25.TkSZ_err, fmt='o', label='Ried-Guachalla 2025', capsize=5)

for ax in axs: ax.legend()
plt.show()

# %% [markdown]
# # Catalog Data

# %% [markdown]
# p = self.p0 | pdict | kwargs

# %% [markdown]
# # HODs

# %% [markdown]
# # SHMRs

# %% [markdown]
# # Profiles
