# %%
from Basics import *
setplot(dark=True)

import Measurements, SHMRs, HMFs, HODs, Profiles, SMFs, ForwardModel

from cobaya.samplers.mcmc import plot_progress
from cobaya.model import get_model
from cobaya.yaml import yaml_load_file
from cobaya.run import run

# %%
model = get_model("/global/homes/c/cpopik/Capybara/runchains.yaml")
# Out:
# 2025-07-09 08:39:55.016803: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-09 08:39:55.016859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-09 08:39:55.018633: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-09 08:39:55.029209: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-09 08:39:56.257690: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'thingtest']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'thingtest']
# Loading Data
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = get_model("/global/homes/c/cpopik/Capybara/runchains.yaml")
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/model.py:1371, in get_model(info_or_yaml_or_file, debug, stop_at_error, packages_path, override)
#    1367     get_logger(__name__).debug(
#    1368         "Input info updated with defaults (dumped to YAML):\n%s",
#    1369         yaml_dump(sort_cosmetic(updated_info)))
#    1370 # Initialize the parameters and posterior
# -> 1371 return Model(updated_info["params"], updated_info["likelihood"],
#    1372              updated_info.get("prior"), updated_info.get("theory"),
#    1373              packages_path=info.get("packages_path"),
#    1374              timing=updated_info.get("timing"),
#    1375              stop_at_error=info.get("stop_at_error", False))
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/model.py:247, in Model.__init__(self, info_params, info_likelihood, info_prior, info_theory, packages_path, timing, allow_renames, stop_at_error, post, skip_unused_theories, dropped_theory_params)
#     244 self.theory = TheoryCollection(info_theory or {}, packages_path=packages_path,
#     245                                timing=timing)
#     246 info_likelihood = self._updated_info["likelihood"]
# --> 247 self.likelihood = LikelihoodCollection(info_likelihood, theory=self.theory,
#     248                                        packages_path=packages_path, timing=timing)
#     249 if stop_at_error:
#     250     for component in self.components:
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/likelihood.py:276, in LikelihoodCollection.__init__(self, info_likelihood, packages_path, timing, theory)
#     271     assert isinstance(info, Mapping)
#     272     like_class: type = get_component_class(
#     273         name, kind="likelihood",
#     274         component_path=info.get("python_path"),
#     275         class_name=info.get("class"), logger=self.log)
# --> 276     self.add_instance(name, like_class(info, packages_path=packages_path,
#     277                                        timing=timing, standalone=False,
#     278                                        name=name))
#     280 if not is_LikelihoodInterface(self[name]):
#     281     raise LoggedError(self.log, "'Likelihood' %s is not actually a "
#     282                                 "likelihood (no current_logp attribute)",
#     283                       name)
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/likelihood.py:94, in Likelihood.__init__(self, info, name, timing, packages_path, initialize, standalone)
#      88 def __init__(self, info: LikeDictIn = empty_dict,
#      89              name: Optional[str] = None,
#      90              timing: Optional[bool] = None,
#      91              packages_path: Optional[str] = None,
#      92              initialize=True, standalone=True):
#      93     self.delay = 0
# ---> 94     super().__init__(info, name=name, timing=timing,
#      95                      packages_path=packages_path, initialize=initialize,
#      96                      standalone=standalone)
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/theory.py:65, in Theory.__init__(self, info, name, timing, packages_path, initialize, standalone)
#      59 def __init__(self, info: TheoryDictIn = empty_dict,
#      60              name: Optional[str] = None, timing: Optional[bool] = None,
#      61              packages_path: Optional[str] = None,
#      62              initialize=True, standalone=True):
#      64     self._measured_speed = None
# ---> 65     super().__init__(info, name=name, timing=timing,
#      66                      packages_path=packages_path, initialize=initialize,
#      67                      standalone=standalone)
#      69     # set to Provider instance before calculations
#      70     self.provider: Optional['Provider'] = None
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/cobaya/component.py:367, in CobayaComponent.__init__(self, info, name, timing, packages_path, initialize, standalone)
#     365 try:
#     366     if initialize:
# --> 367         self.initialize()
#     368 except AttributeError as e:
#     369     if '_params' in str(e):
#
# File /global/u2/c/cpopik/Capybara/SOLikelihoods.py:33, in SZLikelihood.initialize(self)
#      30 self.cpars = {k: v["value"] for k, v in yaml_load_file(self.yaml_file)['params'].items() if isinstance(v, dict) and "value" in v}
#      32 print("Loading Data")
# ---> 33 self._get_data()
#      35 print("Loading Cosmology functions")
#      36 self.cosmology = astropy.cosmology.LambdaCDM(H0=self.initpar["hh"]*100, Tcmb0=2.726, Om0=self.initpar["Omega_m"], Ode0=self.initpar["Omega_L"], Ob0=self.initpar["Omega_b"])
#
# File /global/u2/c/cpopik/Capybara/SOLikelihoods.py:81, in TSZLikelihood._get_data(self)
#      80 def _get_data(self):
# ---> 81     self.meas = getattr(Measurements, self.DataUse['name'])(self.DataUse['spefs']).tSZdata_in_muK(self.cpars)
#      83     self.data = GaussianData("SZModel", self.thetas, self.meas.tSZdata, self.tSZcov)
#
# TypeError: Schaan2021.__init__() takes 1 positional argument but 2 were given

# %%
model = get_model("/global/homes/c/cpopik/Git/Capybara/cobayatest_chains.yaml").likelihood['cobayatest_py.TSZLikelihoodTEST']

plt.errorbar(model.thetas, model.meas, np.diag(model.cov)**0.5, label='Data')
plt.plot(model.thetas, model._get_theory(model.initpar), label='Guess')
plt.legend()
# Out:
# WARNING:model:Ignored blocks/options: ['sampler', 'output']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output']
# /global/u2/c/cpopik/Git/Capybara/SMFs.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.SMF = self.SMF_unweighted*self.zdistdf.groupby('zbin')[f"{bin}_{hemisphere}"].sum().values/np.trapz(self.SMF_unweighted, self.mstars, axis=0)
# Loading Data
# Loading Cosmology functions
# Loading SMF
# Loading SHMR
# Loading HMF
# Loading HOD
# Loading FFT
# Loading FFT
# Test calculation
# Data: [ -0.03642943  -0.07246018  -1.08030807  -2.19914844  -3.98545661
#   -6.19559573  -8.43387307 -11.72230438 -15.13739493], Theory: [ -0.02681449  -1.06377127  -2.57815483  -4.18564782  -5.7131645
#   -7.05971726  -8.20542515  -9.28191209 -10.46457503]

# %%
results = pd.DataFrame(np.genfromtxt("/global/homes/c/cpopik/Git/Capybara/cobayatest/chains_TEST/cobaya_TEST_0.001.1.txt", names=True).T)

plot_progress("cobayatest/chains_TEST/cobaya_TEST_0.001", figure_kwargs={"figsize": (6,4)})

plt.tight_layout()
plt.show()

results.columns
# Out:
# Index(['weight', 'minuslogpost', 'A0_P0', 'alpha_GNFW', 'A0_beta', 'A2h',
#        'minuslogprior', 'minuslogprior__0', 'chi2',
#        'chi2__cobayatest_pyTSZLikelihoodTEST'],
#       dtype='object')

# %%
params = ['A0_P0', 'alpha_GNFW', 'A0_beta', 'A2h']
pvals = [2, 0.8, 2.6, 0.7]

fig, axs = plt.subplots(2, 2, figsize=(12, 8), layout='constrained')
for ax, param, pval in zip(axs.flatten(), params, pvals):
    ax.hist(results[param], 100, density=True, label='all')
    ax.hist(results[param][-1000::], 100, density=True, alpha=0.8, label='Recent')
    ax.axvline(pval, c='r')
    ax.legend(title=param)

results.shape
# Out:
# (3697, 10)

# %%
info_from_yaml = yaml_load_file("/global/homes/c/cpopik/Git/Capybara/cobayatest_chains.yaml")
updated_info_minimizer, minimizer = run(info_from_yaml, minimize=True, force=True)
minimum = minimizer.products()["minimum"]

plt.errorbar(model.thetas, model.meas, np.diag(model.cov)**0.5, label='Data')
plt.plot(model.thetas, model._get_theory(model.initpar), label='Guess')
plt.plot(model.thetas, model._get_theory(model.initpar | dict(minimum.MAP())), label='Fit')
plt.legend()
# Out:
# INFO:output:Output to be read-from/written-into folder 'cobayatest/chains_TEST', with prefix 'cobaya_TEST_0.001'
# [output] Output to be read-from/written-into folder 'cobayatest/chains_TEST', with prefix 'cobaya_TEST_0.001'
# INFO:output:Found existing info files with the requested output prefix: 'cobayatest/chains_TEST/cobaya_TEST_0.001'
# [output] Found existing info files with the requested output prefix: 'cobayatest/chains_TEST/cobaya_TEST_0.001'
# INFO:output:Will delete previous products ('force' was requested).
# [output] Will delete previous products ('force' was requested).
# /global/u2/c/cpopik/Git/Capybara/SMFs.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   self.SMF = self.SMF_unweighted*self.zdistdf.groupby('zbin')[f"{bin}_{hemisphere}"].sum().values/np.trapz(self.SMF_unweighted, self.mstars, axis=0)
# Loading Data
# Loading Cosmology functions
# Loading SMF
# Loading SHMR
# Loading HMF
# INFO:minimize:Initializing
# Loading HOD
# Loading FFT
# Loading FFT
# Test calculation
# Data: [ -0.03642943  -0.07246018  -1.08030807  -2.19914844  -3.98545661
#   -6.19559573  -8.43387307 -11.72230438 -15.13739493], Theory: [ -0.02681449  -1.06377127  -2.57815483  -4.18564782  -5.7131645
#   -7.05971726  -8.20542515  -9.28191209 -10.46457503]
# [minimize] Initializing
# INFO:samplecollection:Loaded 38720 sample points from 'cobayatest/chains_TEST/cobaya_TEST_0.001.1.txt'
# [samplecollection] Loaded 38720 sample points from 'cobayatest/chains_TEST/cobaya_TEST_0.001.1.txt'
# INFO:minimize:Run 1/2 will start from MAP of previous sample:
# [minimize] Run 1/2 will start from MAP of previous sample:
# INFO:minimize:{'A0_P0': 0.59016475, 'alpha_GNFW': 0.55833653, 'A0_beta': 1.2117117, 'A2h': 1.8592474}
# [minimize] {'A0_P0': 0.59016475, 'alpha_GNFW': 0.55833653, 'A0_beta': 1.2117117, 'A2h': 1.8592474}
# INFO:minimize:Run 2/2 will start from random initial point:
# [minimize] Run 2/2 will start from random initial point:
# INFO:minimize:{'A0_P0': 2.0, 'alpha_GNFW': 0.8, 'A0_beta': 2.6, 'A2h': 0.7}
# [minimize] {'A0_P0': 2.0, 'alpha_GNFW': 0.8, 'A0_beta': 2.6, 'A2h': 0.7}
# INFO:minimize:Covariance matrix from previous sample.
# [minimize] Covariance matrix from previous sample.
# INFO:minimize:Starting run 1/2
# [minimize] Starting run 1/2
# INFO:minimize:Run 1/2 converged.
# [minimize] Run 1/2 converged.
# INFO:minimize:Starting run 2/2
# [minimize] Starting run 2/2
# INFO:minimize:Run 2/2 converged.
# [minimize] Run 2/2 converged.
# INFO:minimize:Finished successfully!
# [minimize] Finished successfully!
# WARNING:minimize:Modest spread in minima: [77.74448015521578, 78.62548422602138]
# [minimize] *WARNING* Modest spread in minima: [77.74448015521578, 78.62548422602138]
# INFO:minimize:-log(posterior) minimized to 77.7445
# [minimize] -log(posterior) minimized to 77.7445
# INFO:minimize:Parameter values at minimum:
#    weight  minuslogpost     A0_P0  alpha_GNFW   A0_beta       A2h  minuslogprior  minuslogprior__0        chi2  chi2__cobayatest_py.TSZLikelihoodTEST
# 0     1.0      77.74448  0.589552    0.537987  1.209332  0.204431       7.846375          7.846375  139.796211                             139.796211
# [minimize] Parameter values at minimum:
#    weight  minuslogpost     A0_P0  alpha_GNFW   A0_beta       A2h  minuslogprior  minuslogprior__0        chi2  chi2__cobayatest_py.TSZLikelihoodTEST
# 0     1.0      77.74448  0.589552    0.537987  1.209332  0.204431       7.846375          7.846375  139.796211                             139.796211
# INFO:minimize:Full set of minima:
# {'0': (77.74448015521578, True), '1': (78.62548422602138, True)}
# [minimize] Full set of minima:
# {'0': (77.74448015521578, True), '1': (78.62548422602138, True)}

# %% [markdown]
# # Dust Profiles

# %%
schaan = Measurements.Schaan2021()

fact = (schaan.T_CMB*1e6)*(Measurements.fnu(schaan.freq, schaan.T_CMB))*4.54591666
plt.errorbar(schaan.thetas, schaan.tSZdata*fact, -schaan.tSZerr*fact)
plt.plot(schaan.thetas, schaan.dustprof*fact)

np.genfromtxt("/global/homes/c/cpopik/fig6_TNG_H_dust.txt").T

# %%
A_dust = 0.2
T_dust = 20*u.K
beta_dust = 1.1
c0 = 6
c1 = -2
c2 = 0.1
nu0 = (c.c/(800*1e-6*u.m)).to(u.GHz)
z = 0.55

def dust(nu, R):
    x = lambda nu: np.exp((nu*c.h/c.k_B/T_dust).decompose()) - 1
    return A_dust*(nu*(1+z)/nu0)**(beta_dust+3) * x(nu0)/x(nu*(1+z)) * (c0+c1*R+c2*R**2) * (u.kJy/u.sr)

# %%
plt.plot(model.thetas, dust(150*u.GHz, model.thetas))

# %%
(dust(150*u.GHz, model.thetas)*c.sigma_T/c.c**2/c.m_e*4*np.pi*u.sr).decompose()
# Out:
# <Quantity [ 2.84056231e-23,  2.08820301e-23,  1.38997027e-23,
#             7.45864112e-24,  1.55884517e-24, -3.79968510e-24,
#            -8.61694968e-24, -1.28929486e-23, -1.66276818e-23] kg / s2>
