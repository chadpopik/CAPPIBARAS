# %%
# Imports
from config import *

# %% [markdown]
# # Stacking

# %% [markdown]
# ### Load Measurements

# %%
importlib.reload(Measurements)

# Print options that we can choose from
print(Measurements.Liu2025.subs)
print(Measurements.RiedGuachalla2025.subs)

# Dictionaries that can be created and altered in a yaml file
tSZdict = {'Measurement': {'name': 'Liu2025', 'spefs': {'zbin':'z1', 'ACTDR':'DR6', 'dp':'dBeta', 'Beta':'1.2', 'TCIB':'10.7'}}}
kSZdict = {'Measurement': {'name': 'RiedGuachalla2025', 'spefs': {'bin':'z_1'}}}

# Load the objects using the dictionaries
tSZmeas = getattr(Measurements, tSZdict['Measurement']['name'])(tSZdict['Measurement']['spefs'])
kSZmeas = getattr(Measurements, kSZdict['Measurement']['name'])(kSZdict['Measurement']['spefs'])
# Out:
# {'zbin': ['z1', 'z2', 'z3', 'z4'], 'ACTDR': ['DR5', 'DR6'], 'dp': ['beta', 'dBeta'], 'Beta': ['fiducial', '1.2', '1.4', '1.6'], 'TCIB': ['10.7', '24.0'], 'aper': ['CAP', 'RingRing'], 'freq': ['090', '150']}
# {'bin': ['all', 'z_1', 'z_2', 'z_3', 'z_4', 'mass_1', 'mass_2', 'mass_3', 'mass_4']}

# %%
# Plot the measurements
fig, axs = plt.subplots(1, 2, figsize=(15, 5), layout='constrained')
axs[0].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{tSZ} [\mu \text{K arcmin}]$')
axs[1].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{kSZ} [\mu \text{K arcmin}]$', yscale='log')

axs[0].errorbar(tSZmeas.R, tSZmeas.y_data, tSZmeas.y_err, marker='o', ls='', label='Liu 2025')
axs[1].errorbar(kSZmeas.R, kSZmeas.TkSZ_data, kSZmeas.TkSZ_err, marker='o', ls='', label='Ried-Guachalla 2025')

axs[0].legend(); axs[1].legend()
plt.show()

# %% [markdown]
# ## Load Halo Model

# %%
importlib.reload(HaloModels)

print(HaloModels.pyccl_model.options)
print(HaloModels.pyccl_model.Parameters)

# Specify the halo model using and all specification we need to use
hmoddict = {'HaloModel': {
                'name':'pyccl_model', 
                'spefs': {'MassDef':'200c','MassFunc':'Tinker08', 'HaloBias':'Tinker10', 'Concentration':'Diemer15', 'PowSpec':'LINEAR'}}}

# Make a selection of cosmo params that will exist in in a yaml file
cosmopars = {'h':0.7, 'Om0':0.25, 'Ob0':0.044, 'T_CMB':2.7255}

# Load the objects using the dictionaries
halomodel = getattr(HaloModels, hmoddict['HaloModel']['name'])(hmoddict['HaloModel']['spefs'], **cosmopars)
# Out:
# {'TransFunc': ['BBKS', 'EISENSTEIN_HU', 'EISENSTEIN_HU_NOWIGGLES', 'BOLTZMANN_CLASS', 'BOLTZMANN_CAMB', 'BOLTZMANN_ISITGR', 'CALCULATOR', 'EMULATOR_LINPK'], 'PowSpec': ['LINEAR', 'HALOFIT', 'CAMB', 'CALCULATOR', 'EMULATOR_NLPK'], 'MassDef': ['200c', '200m', '500c', 'Fof', 'Vir'], 'MassFunc': ['Angulo12', 'Bocquet16', 'Bocquet20', 'Despali16', 'Jenkins01', 'Nishimichi19', 'Press74', 'Sheth99', 'Tinker08', 'Tinker10', 'Watson13'], 'HaloBias': ['Bhattacharya11', 'Sheth01', 'Sheth99', 'Tinker10'], 'Concentration': ['Bhattacharya13', 'Constant', 'Diemer15', 'Duffy08', 'Ishiyama21', 'Klypin11', 'Prada12']}
# ['Omega_c', 'Omega_b', 'h', 'n_s', 'sigma8', 'A_s', 'Omega_k', 'Omega_g', 'Neff', 'm_nu', 'mass_split', 'w0', 'wa', 'T_CMB', 'T_ncdm', 'extra_parameters', 'transfer_function', 'matter_power_spectrum', 'baryonic_effects', 'mg_parametrization']

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10), layout='constrained')
axs=axs.flatten()

zs = np.linspace(0, 3, 100)

axs[0].set(ylabel=r'$H(z) \ [\text{km/s/Mpc}]$', xlabel=r'$z$')
axs[0].plot(zs, halomodel.H(zs))

axs[1].set(ylabel=r'$\chi(z) \ [\text{Mpc}]$', xlabel=r'$z$')
axs[1].plot(zs, halomodel.chi(zs))

axs[2].set(ylabel=r'$d_A(z) \ [\text{Mpc}]$', xlabel=r'$z$')
axs[2].plot(zs, halomodel.dA(zs))

axs[3].set(ylabel=r'$\rho_c(z) \ [M_\odot/\text{Mpc}^3]$', xlabel=r'$z$')
axs[3].plot(zs, halomodel.rhoc(zs))


logMh, z = np.linspace(10, 16, 100), 0.5

axs[4].set(ylabel=r'$c(z, M_h) \ []$', xlabel=rf'$M_h \ ({halomodel.MassDef}) \ [M_\odot]$')
axs[4].plot(logMh, halomodel.c(z, logMh))

axs[5].set(ylabel=r'$b_h(z, M_h) \ []$', xlabel=rf'$M_h \ ({halomodel.MassDef}) \ [M_\odot]$')
axs[5].plot(logMh, halomodel.bh(z, logMh))

axs[6].set(ylabel=r'$\frac{dn_h(z, M_h)}{d\log_{10} M_h}$ [Mpc$^{-3}$]', xlabel=rf'$M_h \ ({halomodel.MassDef}) \ [M_\odot]$', yscale='log')
axs[6].plot(logMh, halomodel.dndlogm(z, logMh))


ks = np.logspace(-3, 1, 100)

axs[7].set(ylabel=r'$P_\text{lin}(k, z) \ [\text{Mpc}^3]$', xlabel=r'$k \ [\text{Mpc}^{-1}]$')
axs[7].loglog(ks, halomodel.Plin(ks, z))

plt.show()

# %% [markdown]
# # Load Data

# %%
importlib.reload(MapData)

ACTDR6 = MapData.Coulton2024()

fig, axs = plt.subplots(1, 2, figsize=(8, 4), layout='constrained')

axs[0].set(xlabel=r'$\ell$', ylabel=r'$B_\ell \ []$')
axs[0].plot(ACTDR6.beam_ells, ACTDR6.beam_data)

axs[1].set(xlabel=r'$\ell$', ylabel=r'$R_\ell \ []$')

plt.show()

# %%
importlib.reload(TargetData)

targets_ksz = TargetData.RiedGuachalla2025(bin='z_1')
targets_ksz.make_zdists(dz=0.01)
targets_ksz.make_Mhdists(dlogMh=0.05, halomodel=halomodel)

# targets_tsz = TargetData.Liu2025(zbin='z1')
# targets_tsz.make_zdists(dz=0.01)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4), layout='constrained')

axs[0].set(xlabel=r'$z$', ylabel=r'$\frac{dn}{dz} [\text{dex}^{-1}]$')
axs[0].plot(targets_ksz.z, targets_ksz.dndz, label='Ried-Guachalla 2025')

axs[1].set(xlabel=r'$M_h (M_\odot)$', ylabel=r'$\frac{dn}{d\log M_h} [\text{Mpc}^{-3} \text{dex}^{-1}]$', yscale='log')
axs[1].plot(targets_ksz.logMh, targets_ksz.dndlogMh, label='Ried-Guachalla 2025')

axs[0].legend(); axs[1].legend()
plt.show()

# %% [markdown]
# ### Load Profile Model

# %%
importlib.reload(Profiles)

presdict = {'Profile': {'name':'Amodeo2021', 'spefs': {'model':'GNFW'}}}
presmodel = getattr(Profiles, presdict['Profile']['name'])(presdict['Profile']['spefs'])


Nagai07 = Profiles.Nagai2007(Run='Obs', Sample='Rel', rhoc=hmod.rhoc, r500c=hmod.rdel('500c'))


# hmoddict = {'HaloModel': {'name':'pyccl_model', 'spefs': {'MassFunc':'Tinker08', 'MassDef':'200c', 'HaloBias':'Tinker10', 'Concentration':'Diemer15'}},}
# hmod_t = getattr(HaloModels, hmoddict['HaloModel']['name'])(hmoddict['HaloModel']['spefs'])

# hmod_t.HaloBias


# hmoddict

# # Ok, let's define it now for our entire halo mass values

# Pth1h_tSZ = Pth1hmodel.Pth1h(proj_tSZ.rs, tSZmeas.zs, tSZmeas.logmhalos, rhoc, r200c)
# Pth2h_tSZ = Pth2hmodel.Pth2h(proj_tSZ.rs, tSZmeas.zs, tSZmeas.logmhalos, rhoc, r200c, dndlogmhalo, bh, Plin)
# pres = lambda params={}: presmodel.pres()

# rho1h_kSZ = rho1hmodel.rho1h(proj_kSZ.rs, kSZmeas.zs, kSZmeas.logmhalos, rhoc, r200c)
# rho2h_kSZ = rho2hmodel.rho2h(proj_kSZ.rs, kSZmeas.zs, kSZmeas.logmhalos, rhoc, r200c, dndlogmhalo, bh, Plin)
# rho_kSZ = lambda params={}: rho1h_kSZ(params)+rho2h_kSZ(params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 importlib.reload(Profiles)
#       3 presdict = {'Profile': {'name':'Amodeo2021', 'spefs': {'model':'GNFW'}}}
#       4 presmodel = getattr(Profiles, presdict['Profile']['name'])(presdict['Profile']['spefs'])
#
# NameError: name 'importlib' is not defined

# %%
from Models import Profiles
importlib.reload(Profiles)

densdict = {'Profile': {'name':'Amodeo2021', 'spefs': {'model/':'GNFW'}}}
densmodel = getattr(Profiles, densdict['Profile']['name'])(densdict['Profile']['spefs'])

# %%
from Models import Data
importlib.reload(Data)

G23 = Data.Gao2023(sample='LRG')
G23.make_zMsdists()
z_t, logMs_t = G23.zs, G23.logMs

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), layout='constrained')

zcutf = lambda dndz: dndz>10
mcutf = lambda logmhalos: logmhalos<14.5 

for meas in [kSZmeas, tSZmeas, Cggmeas, Cgymeas]:
    zcut = zcutf(meas.dndz)
    axs[0].plot(meas.zs, meas.dndz, label=f'{meas.name}', alpha=0.7)
    axs[0].scatter(meas.zs[zcut], meas.dndz[zcut], marker='.',alpha=0.7, label=f'n_z = {meas.zs[zcut].size}', zorder=100)
    
    # mcut = mcutf(meas.logmhalos)
    # axs[1].plot(kSZmeas.logmhalos, kSZmeas.dNdlogmhalo, label=f'tSZ n_m = {tSZmeas.logmhalos.size}', alpha=0.7)
    # axs[1].plot(kSZmeas.logmhalos[mcut], kSZmeas.dndz[mcut], marker='o', lw=0, alpha=0.7)

axs[0].set(xlabel='z', ylabel='dNdz'); axs[0].legend()
axs[1].set(xlabel='logm', ylabel='dNdlogm'); axs[1].legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# Cell In[8], line 7
#       4 mcutf = lambda logmhalos: logmhalos<14.5
#       6 for meas in [kSZmeas, tSZmeas, Cggmeas, Cgymeas]:
# ----> 7     zcut = zcutf(meas.dndz)
#       8     axs[0].plot(meas.zs, meas.dndz, label=f'{meas.name}', alpha=0.7)
#       9     axs[0].scatter(meas.zs[zcut], meas.dndz[zcut], marker='.',alpha=0.7, label=f'n_z = {meas.zs[zcut].size}', zorder=100)
#
# Cell In[8], line 3, in <lambda>(dndz)
#       1 fig, axs = plt.subplots(1, 2, figsize=(15, 5), layout='constrained')
# ----> 3 zcutf = lambda dndz: dndz>10
#       4 mcutf = lambda logmhalos: logmhalos<14.5
#       6 for meas in [kSZmeas, tSZmeas, Cggmeas, Cgymeas]:
#
# File ~/.conda/envs/soliket-test2/lib/python3.10/site-packages/astropy/units/quantity.py:696, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
# ...

# %%
zs_kSZ = kSZmeas.zs[zcut_kSZ]
zs_tSZ = tSZmeas.zs[zcut_tSZ]
zs_Cgg = Cggmeas.zs[zcut_Cgg]
zs_Cgy = Cgymeas.zs[zcut_Cgy]

dNdz_kSZ = kSZmeas.dNdz[zcut_kSZ]
dNdz_tSZ = tSZmeas.dNdz[zcut_tSZ]
dNdz_Cgg = Cggmeas.dNdz[zcut_Cgg]
dNdz_Cgy = Cgymeas.dNdz[zcut_Cgy]

logmhalos_kSZ = kSZmeas.logmhalos[mcut_kSZ]
logmhalos_tSZ = tSZmeas.logmhalos[mcut_tSZ]
logmhalos_Cgg = Cggmeas.logmhalos[mcut_Cgg]
logmhalos_Cgy = Cgymeas.logmhalos[mcut_Cgy]

# %%
# Load in all functions we'll need

from Models import HaloModels
importlib.reload(HaloModels)

# For simple cosmological functions, we can use astropy
cosmopars = {'H0':cpars["hh"]*100, 'Om0':cpars["Omega_m"], 'Ob0':cpars["Omega_b"], 'Tcmb0':cpars["T_CMB"] }
cosmology = astropy.cosmology.Planck18.clone(cosmopars)
H = lambda zs: astropy.cosmology.Planck18.H(zs).to(u.km/u.s/u.Mpc).value
rhoc = lambda zs: astropy.cosmology.Planck18.critical_density(zs).to(u.Msun/u.Mpc**3).value
dA = lambda zs: astropy.cosmology.Planck18.angular_diameter_distance(zs).value
chi = lambda zs: astropy.cosmology.Planck18.comoving_distance(zs).value
r200c = lambda zs, logmhalos: (10**logmhalos/(4/3*np.pi*200*rhoc(zs)))**(1/3)

# More complicated cosmological functions we need from Halo Models
halodict = {'HMF': {'name':'pyccl', 
                    'spefs': {'mfunc':'Tinker08', 'mdef':'200c', 'hbias':'Tinker10', 'concmod':'Diemer15'}},}
hmod = getattr(HaloModels, halodict['HMF']['name'])(halodict['HMF']['spefs'])
dndlogmhalo = lambda zs, logmhalos: hmod.HMF(zs, logmhalos)
bh = lambda zs, logmhalos: hmod.bh(zs, logmhalos)
conc = lambda zs, logmhalos: hmod.conc(zs, logmhalos)
Plin = lambda ks, zs: hmod.Plin(ks, zs)

# %%
# Initialize our projections from some 3D average profile/power spectra to 2D angular
# These are are built off of info from our data and basic cosmological functionss

from Models import Projections, Spectra
importlib.reload(Projections); importlib.reload(Spectra)

# modeled 3D average radial profiles -> observed 2D projected signals
proj_kSZ = Projections.Popik2025(tSZmeas.R, dA(tSZmeas.zmean), tSZmeas.beam_ells, tSZmeas.beam_data, tSZmeas.resp_ells, tSZmeas.resp_data)
proj_tSZ = Projections.Popik2025(kSZmeas.R, dA(kSZmeas.zmean), kSZmeas.beam_ells, kSZmeas.beam_data, kSZmeas.resp_ells, kSZmeas.resp_data)

# moeled 3D power spectra -> observered 2D angular power spectra
proj_Cgg = Spectra.Popik2025(Cggmeas.ell, Cggmeas.zs, Cggmeas.dNdz, chi, H)
proj_Cgy = Spectra.Popik2025(Cgymeas.ell, Cgymeas.zs, Cgymeas.dNdz, chi, H, Cgymeas.beam_ells, Cgymeas.beam_data)

# %%
# The data defines our redshifts and masses, the projection defines our ks/rs

from Models import Profiles
importlib.reload(Profiles)

pthdict = {'onehalo': {'name':'Amodeo2021', 
                        'spefs': {'model':'GNFW'}},
            'twohalo': {'name':'Amodeo2021', 
                        'spefs': {'model':'GNFW'}}}

rhodict = {'onehalo': {'name':'Amodeo2021', 
                        'spefs': {'model':'GNFW'}},
            'twohalo': {'name':'Amodeo2021', 
                        'spefs': {'model':'GNFW'}}}

Pth1hmodel = getattr(Profiles, pthdict['onehalo']['name'])(pthdict['onehalo']['spefs'])
Pth2hmodel = getattr(Profiles, pthdict['twohalo']['name'])(pthdict['twohalo']['spefs'])
rho1hmodel = getattr(Profiles, rhodict['onehalo']['name'])(rhodict['onehalo']['spefs'])
rho2hmodel = getattr(Profiles, rhodict['twohalo']['name'])(rhodict['twohalo']['spefs'])

# Ok, let's define it now for our entire halo mass values

Pth1h_tSZ = Pth1hmodel.Pth1h(proj_tSZ.rs, tSZmeas.zs, tSZmeas.logmhalos, rhoc, r200c)
Pth2h_tSZ = Pth2hmodel.Pth2h(proj_tSZ.rs, tSZmeas.zs, tSZmeas.logmhalos, rhoc, r200c, dndlogmhalo, bh, Plin)
Pth_tSZ = lambda params={}: Pth1h_tSZ(params)+Pth2h_tSZ(params)

rho1h_kSZ = rho1hmodel.rho1h(proj_kSZ.rs, kSZmeas.zs, kSZmeas.logmhalos, rhoc, r200c)
rho2h_kSZ = rho2hmodel.rho2h(proj_kSZ.rs, kSZmeas.zs, kSZmeas.logmhalos, rhoc, r200c, dndlogmhalo, bh, Plin)
rho_kSZ = lambda params={}: rho1h_kSZ(params)+rho2h_kSZ(params)

Pth1h_Cgy = Pth1hmodel.Pth1h(proj_Cgy.rs, Cgymeas.zs, Cgymeas.logmhalos, rhoc, r200c)
Pth2h_Cgy = Pth2hmodel.Pth2h(proj_Cgy.rs, Cgymeas.zs, Cgymeas.logmhalos, rhoc, r200c, dndlogmhalo, bh, Plin)
Pth_Cgy = lambda params={}: Pth1h_Cgy(params)+Pth2h_Cgy(params)

# %%
# Let's take a look at profile model at average values

Pth1h_mean_tSZ = Pth1hmodel.Pth1h(proj_tSZ.rs, tSZmeas.zmean, tSZmeas.logmhalomean, rhoc, r200c)
Pth2h_mean_tSZ = Pth2hmodel.Pth2h(proj_tSZ.rs, tSZmeas.zmean, tSZmeas.logmhalomean, rhoc, r200c, dndlogmhalo, bh, Plin)
Pth_mean_tSZ = lambda params={}: Pth1h_mean_tSZ(params)+Pth2h_mean_tSZ(params)

rho1h_mean_ksz = rho1hmodel.rho1h(proj_kSZ.rs, kSZmeas.zmean, kSZmeas.logmhalomean, rhoc, r200c)
rho2h_mean_ksz = rho2hmodel.rho2h(proj_kSZ.rs, kSZmeas.zmean, kSZmeas.logmhalomean, rhoc, r200c, dndlogmhalo, bh, Plin)
rho_mean_ksz = lambda params={}: rho1h_mean_ksz(params)+rho2h_mean_ksz(params)

Pth1h_mean_Cgy = Pth1hmodel.Pth1h(proj_Cgy.rs, Cgymeas.zmean, Cgymeas.logmhalomean, rhoc, r200c)
Pth2h_mean_Cgy = Pth2hmodel.Pth2h(proj_Cgy.rs, Cgymeas.zmean, Cgymeas.logmhalomean, rhoc, r200c, dndlogmhalo, bh, Plin)
Pth_mean_Cgy = lambda params={}: Pth1h_mean_Cgy(params)+Pth2h_mean_Cgy(params)



fig, axs = plt.subplots(1, 2, figsize=(15, 5), layout='constrained', sharex=True)

axs[0].loglog(proj_tSZ.rs, Pth_mean_tSZ()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of tSZ meas', c='coral')
axs[0].loglog(proj_tSZ.rs, Pth1h_mean_tSZ()[:, 0, 0], ls='--', lw=1, c='coral')
axs[0].loglog(proj_tSZ.rs, Pth2h_mean_tSZ()[:, 0, 0], ls='--', lw=1, c='coral')

axs[0].loglog(proj_Cgy.rs, Pth_mean_Cgy()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of Cgy meas', c='skyblue')
axs[0].loglog(proj_Cgy.rs, Pth1h_mean_Cgy()[:, 0, 0], ls='--', lw=1, c='skyblue')
axs[0].loglog(proj_Cgy.rs, Pth2h_mean_Cgy()[:, 0, 0], ls='--', lw=1, c='skyblue')

axs[1].loglog(proj_kSZ.rs, rho_mean_ksz()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of kSZ meas', c='coral')
axs[1].loglog(proj_kSZ.rs, rho1h_mean_ksz()[:, 0, 0], ls='--', lw=1, c='coral')
axs[1].loglog(proj_kSZ.rs, rho2h_mean_ksz()[:, 0, 0], ls='--', lw=1, c='coral')

axs[0].plot(Profiles.rs_sim, Profiles.pths_sim, ls=':', label='Random Galaxy in CAMELS')
axs[0].plot(Profiles.pths_rs_tng, Profiles.pths_tng, ls=':', label='Emily TNG ave')

axs[1].plot(Profiles.rs_sim, Profiles.rhos_sim, ls=':', label='Random Galaxy in CAMELS')
axs[1].plot(Profiles.rhos_rs_tng, Profiles.rhos_tng, ls=':', label='Emily TNG ave')

axs[0].set(ylabel=r'$P_\text{th}(r)$ [dyne cm$^{-2}$]', xlabel=r'$r$ [Mpc]', ylim=(1e-15, 1e-11)); axs[0].legend(title=f'')
axs[1].set(ylabel=r'$\rho_\text{gas}(r)$ [g cm$^{-3}]$', xlabel=r'$r$ [Mpc]', ylim=(1e-31, 1e-26), xlim=(1e-2, 1e1)); axs[1].legend(title=f'')
plt.show()

# %%
from Models import HODs
importlib.reload(HODs)

# Load in our HOD
HODdict = {'HOD': {'name':'Yuan2023', 
                    'spefs': {'sample':'LRG 0.4<z<0.6'}}}


hod = getattr(HODs, HODdict['HOD']['name'])(HODdict['HOD']['spefs'])

# Define HOD functions and setup another method of averaging
Nc, Ns, uck = hod.Nc(tSZmeas.logmhalos), hod.Ns(tSZmeas.logmhalos), hod.uck()
usk, usk_ks = hod.usk(proj_tSZ.rs, tSZmeas.zs, tSZmeas.logmhalos, r200c)
profave_tSZ = proj_tSZ.HODweighting(Nc, Ns, uck, usk, tSZmeas.logmhalos, dndlogmhalo, tSZmeas.zs, usk_ks, tSZmeas.dNdz)

Nc, Ns, uck = hod.Nc(kSZmeas.logmhalos), hod.Ns(kSZmeas.logmhalos), hod.uck()
usk, usk_ks = hod.usk(proj_kSZ.rs, kSZmeas.zs, kSZmeas.logmhalos, r200c)
profave_kSZ = proj_kSZ.HODweighting(Nc, Ns, uck, usk, kSZmeas.logmhalos, dndlogmhalo, kSZmeas.zs, usk_ks, kSZmeas.dNdz)

Nc_gg, Ns_gg, uck_gg = hod.Nc(Cggmeas.logmhalos), hod.Ns(Cggmeas.logmhalos), hod.uck()
usk_gg, usk_ks = hod.usk(proj_Cgg.rs, Cggmeas.zs, Cggmeas.logmhalos, r200c)
P_gg_HOD = proj_Cgg.P_gg(Cggmeas.logmhalos, dndlogmhalo(Cggmeas.zs, Cggmeas.logmhalos), bh(Cggmeas.zs, Cggmeas.logmhalos), Plin(proj_Cgg.ks, Cggmeas.zs))
P1h_gg_HOD = proj_Cgg.P1h_gg(Cggmeas.logmhalos, dndlogmhalo(Cggmeas.zs, Cggmeas.logmhalos))
P2h_gg_HOD = proj_Cgg.P2h_gg(Cggmeas.logmhalos, dndlogmhalo(Cggmeas.zs, Cggmeas.logmhalos), bh(Cggmeas.zs, Cggmeas.logmhalos), Plin(proj_Cgg.ks, Cggmeas.zs))
P1h_gg = lambda p={}: P1h_gg_HOD(Nc_gg(p), Ns_gg(p), uck_gg(p), usk_gg(p))
P2h_gg = lambda p={}: P2h_gg_HOD(Nc_gg(p), Ns_gg(p), uck_gg(p), usk_gg(p))
P_gg = lambda p={}: P_gg_HOD(Nc_gg(p), Ns_gg(p), uck_gg(p), usk_gg(p))

Nc, Ns, uck = hod.Nc(Cgymeas.logmhalos), hod.Ns(Cgymeas.logmhalos), hod.uck()
usk, usk_ks = hod.usk(proj_Cgy.rs, Cgymeas.zs, Cgymeas.logmhalos, r200c)

P_gy_HOD = proj_Cgy.P_gy(Cgymeas.logmhalos, H(Cgymeas.zs), dndlogmhalo(Cgymeas.zs, Cgymeas.logmhalos), bh(Cgymeas.zs, Cgymeas.logmhalos), Plin(usk_ks, Cgymeas.zs))
P_gy = lambda Pth, p={}: P_gy_HOD(Pth, Nc(p), Ns(p), uck(p), usk(p))

P1h_gy_HOD = proj_Cgy.P1h_gy(Cgymeas.logmhalos, H(Cgymeas.zs), dndlogmhalo(Cgymeas.zs, Cgymeas.logmhalos))
P1h_gy = lambda Pth, p={}: P1h_gy_HOD(Pth, Nc(p), Ns(p), uck(p), usk(p))

P2h_gy_HOD = proj_Cgy.P2h_gy(Cgymeas.logmhalos, H(Cgymeas.zs), dndlogmhalo(Cgymeas.zs, Cgymeas.logmhalos), bh(Cgymeas.zs, Cgymeas.logmhalos), Plin(usk_ks, Cgymeas.zs))
P2h_gy = lambda Pth, p={}: P2h_gy_HOD(Pth, Nc(p), Ns(p), uck(p), usk(p))
# Out:
# /global/u2/c/cpopik/CAPPIBARAS/Models/HODs.py:33: RuntimeWarning: invalid value encountered in power
#   nsat = ((M-M_0)/M_1)**alpha

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5), layout='constrained', sharex=True)

axs[0].loglog(proj_tSZ.rs, Pth_mean_tSZ()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of tSZ meas', c='coral')
axs[0].loglog(proj_tSZ.rs, profave_tSZ(Pth_tSZ()), lw=3, label='z/m Average Model of tSZ meas', c='skyblue')
axs[0].loglog(proj_tSZ.rs, profave_tSZ(Pth1h_tSZ()), lw=1, c='skyblue')
axs[0].loglog(proj_tSZ.rs, profave_tSZ(Pth2h_tSZ()), lw=1, c='skyblue')

axs[0].loglog(proj_Cgy.rs, Pth_mean_Cgy()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of Cgy meas', c='skyblue')

axs[1].loglog(proj_kSZ.rs, rho_mean_ksz()[:, 0, 0], ls='--', lw=3, label='Model at ave z,M of kSZ meas', c='coral')
axs[1].loglog(proj_kSZ.rs, profave_kSZ(rho_kSZ()), lw=3, label='z/m Average Model of kSZ meas', c='skyblue')
axs[1].loglog(proj_kSZ.rs, profave_kSZ(rho1h_kSZ()), lw=1, c='skyblue')
axs[1].loglog(proj_kSZ.rs, profave_kSZ(rho2h_kSZ()), lw=1, c='skyblue')

axs[0].plot(Profiles.rs_sim, Profiles.pths_sim, ls=':', label='Random Galaxy in CAMELS')
axs[0].plot(Profiles.pths_rs_tng, Profiles.pths_tng, ls=':', label='Emily TNG ave')

axs[1].plot(Profiles.rs_sim, Profiles.rhos_sim, ls=':', label='Random Galaxy in CAMELS')
axs[1].plot(Profiles.rhos_rs_tng, Profiles.rhos_tng, ls=':', label='Emily TNG ave')

axs[0].set(ylabel=r'$P_\text{th}(r)$ [dyne cm$^{-2}$]', xlabel=r'$r$ [Mpc]', ylim=(1e-15, 1e-11)); axs[0].legend(title=f'')
axs[1].set(ylabel=r'$\rho_\text{gas}(r)$ [g cm$^{-3}]$', xlabel=r'$r$ [Mpc]', ylim=(1e-31, 1e-26), xlim=(1e-2, 1e1)); axs[1].legend(title=f'')
plt.show()

# %%
kSZ_uK = proj_kSZ.rho_to_uK()
tSZ_y = proj_tSZ.Pth_to_y()


pover = {'P0': 1, 'A2h_t':2, 'beta_t':5, 'logrho0':1.2, 'beta_k':4, 'A2h_k':2}

Cgg = lambda p={}: proj_Cgg.C_gg()(P_gg(p | pover), p)
C1hgg = lambda p={}: proj_Cgg.C_gg()(P1h_gg(p | pover), p)
C2hgg = lambda p={}: proj_Cgg.C_gg()(P2h_gg(p | pover), p)
Cgy = lambda p={}: proj_Cgy.C_gy()(P_gy(Pth1h_Cgy(p | pover), p))
C1hgy = lambda p={}: proj_Cgy.C_gy()(P1h_gy(Pth1h_Cgy(p | pover), p))
C2hgy = lambda p={}: proj_Cgy.C_gy()(P2h_gy(Pth1h_Cgy(p | pover), p))

# If the y maps don't subtract the CIB, also need to do so for dust
# from Models import Dust
# importlib.reload(Dust)
# dustdict = {'dust': {'name':'Amodeo2021',
#                     'spefs': {'model':'ACT+Hershel'}}}
# tSZdust = getattr(Dust, dustdict['dust']['name'])(dustdict['dust']['spefs'])
# dust_uK = tSZdust.dust_uKarcmin(tSZmeas.R, np.float64(tSZmeas.freq))()
# tSZ_uK = lambda prof: proj.Pth_to_uK()(prof) + dust_uK

# %%
1/np.trapezoid(Cggmeas.dNdz, Cggmeas.zs)
# Out:
# 6.805757067216546e-07

# %%
# # The data defines a

# from Models import SMFs
# importlib.reload(SMFs)

# # Next load in the target catalog distributions over mass and redshift
# tSZdict = {'SMF': {'name': 'Liu2025', 
#                     'spefs': {'zbin':'1'}}}
# halodist = getattr(SMFs, tSZdict['SMF']['name'])(tSZdict['SMF']['spefs'])
# zs, logmhalos = halodist.z, halodist.logmhalo
# dNdz, dndlogmhalo_smf = halodist.dNdz(), halodist.dndlogmhalo()

# # We can use a distribution over mass/redshift to take distribution weighted averages
# dndzdlogmhalo_norm = dndlogmhalo_smf/np.trapezoid(np.trapezoid(dndlogmhalo_smf, logmhalos), zs)
# aveprof_dist = lambda prof: np.trapezoid(np.trapezoid(prof*dndzdlogmhalo_norm, logmhalos), zs)

# # Let's validate it by checking average values for mass and redshift
# logmave = aveprof_dist(logmhalos)
# zave = np.trapezoid(zs*dNdz, zs)/np.trapezoid(dNdz, zs)
# ntot = np.trapezoid(dNdz, zs)
# print(halodist.info)
# print(f"logmave={logmave:.2f}, zave={zave:.2f}, ntot={ntot:.2f}")

# %%
# Plot all the final results
fig, axs = plt.subplots(2, 2, figsize=(15, 10), layout='constrained')
axs = axs.flatten()

axs[0].errorbar(tSZmeas.R, tSZmeas.y_data, tSZmeas.y_err, marker='o', ls='', label='Liu+ 2021')
# axs[0].plot(tSZmeas.R, tSZ_y(aveprof_dist(Pth())), label='GNFW weighted')
axs[0].plot(tSZmeas.R, tSZ_y(profave_tSZ(Pth_tSZ(pover))), label='GNFW HOD')
axs[0].plot(tSZmeas.R, tSZ_y(profave_tSZ(Pth1h_tSZ(pover))), ls='--', label='GNFW HOD 1h')
axs[0].plot(tSZmeas.R, tSZ_y(profave_tSZ(Pth2h_tSZ(pover))), ls='--', label='GNFW HOD 2h')

axs[0].plot(tSZmeas.R, tSZ_y(Pth_mean_tSZ(pover)[:, 0, 0]), label='GNFW at Ave mz')
# axs[0].plot(tSZmeas.R, tSZ_y(pths_sim), ls=':', label='Random Galaxy')
# axs[0].plot(tSZmeas.R, tSZ_y(pths_tng), ls=':', label='Emily TNG')

axs[2].errorbar(kSZmeas.R, kSZmeas.TkSZ_data, kSZmeas.TkSZ_err, marker='o', ls='', label='Ried-Guachalla 2025')
# axs[2].plot(kSZmeas.R, kSZ_uK(aveprof_dist(rho())), label='GNFW weighted')
axs[2].plot(kSZmeas.R, kSZ_uK(profave_kSZ(rho_kSZ(pover))), label='GNFW HOD')
axs[2].plot(kSZmeas.R, kSZ_uK(rho_mean_ksz(pover)[:, 0, 0]), label='GNFW at ave mz')
# axs[2].plot(kSZmeas.R, kSZ_uK(rhos_sim), ls=':', label='Random Galaxy')
# axs[2].plot(kSZmeas.R, kSZ_uK(rhos_tng), ls=':', label='Emily TNG')

axs[1].errorbar(Cggmeas.ell, Cggmeas.Cgg_data, Cggmeas.Cgg_err, marker='o', ls='', label='White 2022')
axs[1].plot(Cggmeas.ell, C1hgg(), ls='--', label='Popik 2025 model 1h')
axs[1].plot(Cggmeas.ell, C2hgg(), ls='--', label='Popik 2025 model 2h')
axs[1].plot(Cggmeas.ell, Cgg(), label='Popik 2025 model')
# axs[1].plot(Cggmeas.ell, C1hgg()*8, ls='--', label='Popik 2025 model 1h but work')
# axs[1].plot(Cggmeas.ell, C2hgg()*8/100, ls='--', label='Popik 2025 model 2h but work')
# axs[1].plot(Cggmeas.ell, 8*np.ones(Cggmeas.ell.size)/np.trapezoid(Cggmeas.dNdz, Cggmeas.zs), label='Popik 2025 SN')
# axs[1].plot(Cggmeas.ell, 8*(C1hgg()+C2hgg()/100+1/np.trapezoid(Cggmeas.dNdz, Cggmeas.zs)), label='Popik 2025 but works')

axs[3].errorbar(Cgymeas.ell, Cgymeas.Cgy_data, Cgymeas.Cgy_err, marker='o', ls='', label='My meas')
axs[3].plot(Cgymeas.ell, C1hgy(), ls='--', label='Popik 2025 model 1h')
axs[3].plot(Cgymeas.ell, C2hgy(), ls='--', label='Popik 2025 model 2h')
axs[3].plot(Cgymeas.ell, Cgy(), label='Popik 2025 model')
# axs[3].plot(Cgymeas.ell, C1hgy()*2, ls='--', label='Popik 2025 model 1h but work')
# axs[3].plot(Cgymeas.ell, C2hgy()*10, ls='--', label='Popik 2025 model 2h but work')
# axs[3].plot(Cgymeas.ell, C1hgy()*2+C2hgy()*10, label='Popik 2025 model. but work')

axs[0].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{tSZ} [\mu \text{K arcmin}]$') ; axs[0].legend()
axs[2].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{kSZ} [\mu \text{K arcmin}]$', yscale='log'); axs[2].legend()
axs[1].set(xlabel=r'$\ell$', ylabel=r'$C_\ell^{gg}$', yscale='log'); axs[1].legend()
axs[3].set(xlabel=r'$\ell$', ylabel=r'$C_\ell^{gy}$', yscale='log', xlim=(0, 2000), ylim=(1e-13, 2e-10)); axs[3].legend()

plt.show()

# %% [markdown]
# # Spectra

# %%
# Load in all our measurements and data

from Models import Measurements
importlib.reload(Measurements)

# Loading in different types of data here
tSZdict = {'data': {'name': 'Liu2025', 
                    'spefs': {'zbin':'z1', 'ACTDR':'DR6', 'dp':'dBeta', 'Beta':'1.2', 'TCIB':'10.7'}}}
kSZdict = {'data': {'name': 'RiedGuachalla2025', 
                    'spefs': {'bin':'z_1'}}}
# Cggdict = {'data': {'name': 'White2022', 
#                     'spefs': {'zbin':'z1'}}}
# Cgydict = {'data': {'name': 'Popik2025', 
#                     'spefs': {'zbin': 'z1', 'deproj':'cib_cibdBeta', 'TCIB':'10.7', 'beta':'1.2'}}}

tSZmeas = getattr(Measurements, tSZdict['data']['name'])(tSZdict['data']['spefs'])
kSZmeas = getattr(Measurements, kSZdict['data']['name'])(kSZdict['data']['spefs'])
# Cggmeas = getattr(Data, Cggdict['data']['name'])(Cggdict['data']['spefs'])
# Cgymeas = getattr(Data, Cgydict['data']['name'])(Cgydict['data']['spefs'])

# Plot the measurements
fig, axs = plt.subplots(2, 2, figsize=(15, 10), layout='constrained')
axs = axs.flatten()

axs[0].errorbar(tSZmeas.R, tSZmeas.y_data, tSZmeas.y_err, marker='o', ls='', label='Liu 2025')
axs[2].errorbar(kSZmeas.R, kSZmeas.TkSZ_data, kSZmeas.TkSZ_err, marker='o', ls='', label='RG 2025')
# axs[1].errorbar(Cggmeas.ell, Cggmeas.Cgg_data, Cggmeas.Cgg_err, marker='o', ls='', label=Cggmeas.name)
# axs[3].errorbar(Cgymeas.ell, Cgymeas.Cgy_data, Cgymeas.Cgy_err, marker='o', ls='', label=Cgymeas.name)

axs[0].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{tSZ} [\mu \text{K arcmin}]$') ; axs[0].legend()
axs[2].set(xlabel=r'$R$ [arcmin]', ylabel=r'$T_\text{kSZ} [\mu \text{K arcmin}]$', yscale='log'); axs[2].legend()
# axs[1].set(xlabel=r'$\ell$', ylabel=r'$C_\ell^{gg}$', yscale='log'); axs[1].legend()
# axs[3].set(xlabel=r'$\ell$', ylabel=r'$C_\ell^{gy}$', yscale='log'); axs[3].legend()

plt.show()

# %%
from Models import SMFs, Data, Spectra
importlib.reload(SMFs)
importlib.reload(Data)
importlib.reload(Spectra)

# Next we need to load in a target distribution (SMF and z dist), we can use the same halos for both measurements here
koudict = {'Data': {'name': 'Zhou2023',
                    'spefs': {'zbin':'1'}},
        'SMF': {'name': 'Zhou2023', 
                    'spefs': {'pzbin':'1', 'hemisphere':'combined', 'sample':'main'}}}
hmfK = getattr(SMFs, koudict['SMF']['name'])(koudict['SMF']['spefs'])
koudata = getattr(Data, koudict['Data']['name'])(koudict['Data']['spefs'])


hmfK.logmhalo = np.linspace(10, 15, 30)
Cgg1hk = Spectra.Kou2023().Cgg1h(koudata.ell, ks, hmfK.z, chi(hmfK.z), H(hmfK.z), hmfK.dNdz(), hod.Nc(hmfK.logmhalo), hod.Ns(hmfK.logmhalo), hod.usk(rs, r200c(hmfK.z, hmfK.logmhalo), fft.FFT3D), hmfK.logmhalo, dndlogmhalo_hmod_func(hmfK.z, hmfK.logmhalo))()
Cgg2hk = Spectra.Kou2023().Cgg2h(koudata.ell, ks, hmfK.z, chi(hmfK.z), H(hmfK.z), hmfK.dNdz(), hod.Nc(hmfK.logmhalo), hod.Ns(hmfK.logmhalo), hod.usk(rs, r200c(hmfK.z, hmfK.logmhalo), fft.FFT3D), hmfK.logmhalo, dndlogmhalo_hmod_func(hmfK.z, hmfK.logmhalo), bh(hmfK.z, hmfK.logmhalo), Plin(ks, hmfK.z))()
SNk = Spectra.Kou2023().SN(koudata.ell, hmfK.info['area'], hmfK.dNdz(), hmfK.z)

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 5), layout='constrained')
ax.set(xscale='log', yscale='log')

for zbin, color in zip(['1', '2', '3', '4'], ['b', 'red', 'green', 'magenta']):
    ax.scatter(koudata.ell, Data.Zhou2023({'zbin':zbin}).cgg, c=color, label=zbin)

onehalo, twohalo = Cgg1hk, Cgg2hk
ax.loglog(koudata.ell, (onehalo+twohalo)+SNk, label='Kou Model M*>11.1', c='skyblue')
ax.loglog(koudata.ell, onehalo, ls='--', c='skyblue')
ax.loglog(koudata.ell, twohalo,ls=':', c='skyblue')
ax.loglog(koudata.ell, SNk, ls=':', c='skyblue')

plt.show()
