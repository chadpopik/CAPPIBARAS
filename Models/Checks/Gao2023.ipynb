# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Gao2023

# %%
importlib.reload(Gao2023)
logMs = np.random.uniform(low=8, high=13, size=50)
G23 = Gao2023.SHMR(logMs = logMs, model='Psat')

# %%
importlib.reload(Gao2023)
fig, ax = Gao2023.Fig7a().full()

logMh = np.linspace(10, 15, 50)
G23 = Gao2023.SHMR(logMh = logMh, model='Psat')
ax.scatter(G23.logMh, G23.logMstar(), alpha=0.5, c='lime', label='LRG+ELG+X')
G23 = Gao2023.SHMR(logMh = logMh, model='Auto')
ax.scatter(G23.logMh, G23.logMstar(), alpha=0.5, c='gold', label='LRG+ELG')
G23 = Gao2023.SHMR(logMh = logMh, model='Cross')
ax.scatter(G23.logMh, G23.logMstar(), alpha=0.5, c='magenta', label='LRG+X')

ax.legend()
plt.show()

# %%
importlib.reload(Gao2023)

fig, axs = Gao2023.Fig2().full()

G23 = Gao2023.TargetData(sample='LRG')
G23.make_zMsdists()
for i, z in enumerate(G23.z):
    axs[0].scatter(G23.logMs, G23.n_logMs_z_h3[i], alpha=0.7, marker='x', label=f'z={z:.2f}')

G23 = Gao2023.TargetData(sample='ELG')
G23.make_zMsdists()
for i, z in enumerate(G23.z):
    axs[1].scatter(G23.logMs, G23.n_logMs_z_h3[i], alpha=0.7, marker='x', label=f'z={z:.2f}')

axs[0].legend(fontsize=10, loc='upper left'); axs[1].legend(fontsize=10, loc='upper left')
plt.show()
