# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Zheng2005

# %%
importlib.reload(Zheng2005)
Zheng2005.Table1().df
# Out:
#      ngbar Model numParams  logMmin  logM1  alpha  sigmalogM     M0  \
# 0   0.0200   SPH        3P    11.67  12.96   0.97        NaN    NaN
# 1   0.0200    SA        3P    11.77  12.96   1.04        NaN    NaN
# 2   0.0100   SPH        3P    12.04  13.26   1.03        NaN    NaN
# 3   0.0100    SA        3P    12.03  13.30   1.02        NaN    NaN
# 4   0.0050   SPH        3P    12.38  13.55   1.18        NaN    NaN
# 5   0.0050    SA        3P    12.34  13.64   1.09        NaN    NaN
# 6   0.0025   SPH        3P    12.68  13.85   1.24        NaN    NaN
# 7   0.0025    SA        3P    12.58  13.91   1.16        NaN    NaN
# 8   0.0200   SPH        5P    11.68    NaN   1.02       0.15  11.86
# 9   0.0200    SA        5P    11.73    NaN   0.96       0.32  12.09
# 10  0.0100   SPH        5P    12.07    NaN   0.94       0.18  12.28
# 11  0.0100    SA        5P    12.02    NaN   1.07       0.26  12.28
# 12  0.0050   SPH        5P    12.36    NaN   1.00       0.15  12.63
# 13  0.0050    SA        5P    12.36    NaN   1.04       0.42  12.28
# 14  0.0025   SPH        5P    12.69    NaN   1.08       0.15  12.94
# 15  0.0025    SA        5P    12.60    NaN   1.03       0.28  12.77
#
#     logM1prime
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8        13.00
# 9        12.87
# 10       13.19
# 11       13.32
# 12       13.45
# 13       13.62
# 14       13.82
# 15       13.86

# %%
importlib.reload(Zheng2005)
fig, axs = Zheng2005.Fig1().full()

logMh = np.linspace(10, 15.5, 25)

for ax, model in zip(axs, ['SPH', 'SA']):
    Z05 = Zheng2005.HOD(model=model, nparams='5P', ng='0.02')
    ax.scatter(10**logMh, Z05.Ncen(logMh)(), marker='X', c='red', alpha=0.8, label='Cen')
    ax.scatter(10**logMh, Z05.Nsat(logMh)(), marker='X', c='blue', alpha=0.8, label='Sat')
    ax.scatter(10**logMh, Z05.Ntot(logMh)(), marker='X', alpha=0.8, c='purple', label='All')
    ax.legend(loc='center left', title=f'{model} 5P 0.02')

plt.show()

# %%
importlib.reload(Zheng2005)
fig, axs = Zheng2005.Fig3().full()

axs = axs.flatten()
logMh = np.linspace(10, 15.5, 50)

configs = [("SPH", "3P"),("SPH", "5P"),("SA",  "3P"),("SA",  "5P")]
for ax, (model, nparams) in zip(axs, configs):
    Z05 = Zheng2005.HOD(model=model, nparams=nparams, ng="0.02")
    ax.set_title(f"{model} {nparams} 0.02", size=15)
    ax.scatter(10**logMh, Z05.Ncen(logMh)(), marker="x", c="red", alpha=0.8, label="Cen")
    ax.scatter(10**logMh, Z05.Nsat(logMh)(), marker="x", c="blue", alpha=0.8, label="Sat")
    ax.scatter(10**logMh, Z05.Ntot(logMh)(), marker="x", c="purple", alpha=0.8, label="All")
    ax.legend(loc="lower center", fontsize=7)

plt.show()
