# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Zhou2023

# %%
importlib.reload(Zhou2023)

fig, axs = Zhou2023.Fig2().full()

# %%
importlib.reload(Zhou2023)

fig, axs = Zhou2023.Fig3().full()
