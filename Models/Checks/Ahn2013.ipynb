# %%
import sys
from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Ahn2013

# %%
importlib.reload(Ahn2013)

Ahn2013.Data().area
# Out:
# <Quantity 6373.2 deg2>
