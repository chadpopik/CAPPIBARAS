# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Xu2023

# %%
importlib.reload(Xu2023)

Xu2023.Table2().df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 importlib.reload(Xu2023)
#       2
# ----> 3 Xu2023.Table2().df
#
# File ~/CAPPIBARAS/Models/Papers/Xu2023/Xu2023.py:62, in Table2.__init__(self, filename)
#      60 def __init__(self, filename=f"{thispath}/Table2.csv"):
#      61     dfraw = pd.read_csv(filename)
# ---> 62     self.df, self.df_errlow, self.df_errhigh = splittable(dfraw)
#
# File ~/CAPPIBARAS/Models/Papers/PlotsTables.py:154, in splittable(df)
#     151 vals, ups, downs = [], [], []
#     153 for s in df[col].astype(str).str.strip():
# --> 154     s = s.replace('−', '-')  # normalize unicode minus (U+2212) to ASCII, incl. as a leading sign
#     155     m = pat.fullmatch(s)
#     156     m_pm = pat_pm.fullmatch(s) if not m else None
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
importlib.reload(Xu2023)
fig, ax = Xu2023.Fig7().full()

logMh = np.linspace(10, 15, 30)
Mhsh = 10**logMh/Xu2023.SHMR().h

ax.scatter(Mhsh, 10**Xu2023.SHMR(form='DP', sample='Main').SHMR(logMh)(), marker='X', alpha=0.5, c='w', label='z<0.2 DP')
ax.scatter(Mhsh, 10**Xu2023.SHMR(form='BP13', sample='Main').SHMR(logMh)(), alpha=0.5, c='w', label='z<0.2 BP13')
ax.scatter(Mhsh, 10**Xu2023.SHMR(form='DP', sample='LOWZ').SHMR(logMh)(), marker='X', alpha=0.5, c='magenta', label='0.2<z<0.4 DP')
ax.scatter(Mhsh, 10**Xu2023.SHMR(form='BP13', sample='LOWZ').SHMR(logMh)(), alpha=0.5, c='magenta', label='0.2<z<0.4 BP13')
ax.scatter(Mhsh, 10**Xu2023.SHMR(form='DP', sample='CMASS').SHMR(logMh)(), marker='X', alpha=0.5, c='cyan', label='0.5<z<0.7 DP')
ax.scatter(Mhsh, 10**Xu2023.SHMR(form='BP13', sample='CMASS').SHMR(logMh)(), alpha=0.5, c='cyan', label='0.5<z<0.7 BP13')

ax.legend(loc='center right')
plt.show()

# %%
importlib.reload(Xu2023)
fig, axs = Xu2023.Fig9().full()

logMh = np.linspace(10, 15, 50)
Mhsh = 10**logMh/Xu2023.SHMR().h

X23 = Xu2023.SHMR({'sample':'Main', 'form':'BP13'})
axs.scatter(Mhsh, 10**X23.SHMR(logMh)()/(10**logMh), alpha=0.5, c='w', label='mine')
# axs.scatter(Mhsh, 10**X23.SHMR(logMh+np.log10(X23.h))()/(10**logMh/X23.h), alpha=0.5, c='cyan', label='mine')
# axs.scatter(10**logMh, 10**X23.SHMR(logMh+np.log10(X23.h))()/(10**logMh/X23.h), alpha=0.5, c='lime', label='mine')

axs.legend()
plt.show()

# %%
importlib.reload(Xu2023)

fig, axs = Xu2023.Fig13().full()
