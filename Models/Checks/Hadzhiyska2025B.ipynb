# %%
import sys
from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Hadzhiyska2025B

# %%
importlib.reload(Hadzhiyska2025B)

Hadzhiyska2025B.Table1_2_3().df
# Out:
#           Sample  Bin  logMcut   logM1  sigmalogM  alpha  kappa  nbar1000  \
# 0       MainLRGs  all   12.683  14.063      0.133  0.848  1.245     0.745
# 1   ExtendedLRGs  all   12.491  14.196      0.108  0.642  0.941     1.254
# 2   BGSlogM>10.5  all   12.133  13.830      0.107  1.219  1.069     3.608
# 3            NaN  NaN      NaN     NaN        NaN    NaN    NaN       NaN
# 4       MainLRGs   z1   12.610  13.910      0.300  1.000  1.300     1.300
# 5       MainLRGs   z2   12.630  14.020      0.180  0.840  1.300     1.090
# 6       MainLRGs   z3   12.730  13.980      0.210  0.960  1.330     0.690
# 7       MainLRGs   z4   12.630  13.970      0.230  0.960  1.280     0.910
# 8            NaN  NaN      NaN     NaN        NaN    NaN    NaN       NaN
# 9   ExtendedLRGs   z1   12.490  13.960      0.240  0.920  1.280     1.580
# 10  ExtendedLRGs   z2   12.440  14.010      0.140  0.760  1.230     1.660
# 11  ExtendedLRGs   z3   12.520  14.050      0.170  0.890  1.230     1.160
# ...

# %%
importlib.reload(Hadzhiyska2025B)
logMs = np.linspace(11.5, 15, 50)

prefix = {'MainLRGs': 'Main', 'ExtendedLRGs': 'Ext', 'BGSlogM>10.5': 'BGS'}

fig, axs = plt.subplots(1, 3, figsize=(10, 3), sharex=True, sharey=True, layout='constrained')

for samp in ['MainLRGs', 'ExtendedLRGs', 'BGSlogM>10.5']:
    color = plt.get_cmap('hsv')(np.random.rand())
    sample = prefix[samp] if samp == 'BGSlogM>10.5' else f'{prefix[samp]}_all'
    model = Hadzhiyska2025B.HOD(sample=sample)
    axs[0].plot(logMs, model.Ncen(logMs)()+model.Nsat(logMs)(), alpha=0.2, lw=2, label=samp, color=color)
    axs[0].plot(logMs, model.Ncen(logMs)(), alpha=0.7, ls='--', lw=1, color=color)
    axs[0].plot(logMs, model.Nsat(logMs)(), alpha=0.7, ls=':', lw=1, color=color)

for ax, samp in zip(axs[1:], ['MainLRGs', 'ExtendedLRGs']):
    for bin in ['all', 'z1', 'z2', 'z3', 'z4']:
        color = plt.get_cmap('hsv')(np.random.rand())
        model = Hadzhiyska2025B.HOD(sample=f'{prefix[samp]}_{bin}')
        ax.plot(logMs, model.Ncen(logMs)()+model.Nsat(logMs)(), alpha=0.2, lw=2, color=color, label=samp+bin)
        ax.plot(logMs, model.Ncen(logMs)(), alpha=0.7, ls='--', lw=1, color=color)
        ax.plot(logMs, model.Nsat(logMs)(), alpha=0.7, ls=':', lw=1, color=color)

for ax in axs:
    ax.legend()
    ax.set(ylim=(-0.1, 4))

plt.show()
