# %%
import sys
from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers import Zehavi2005

# %%
importlib.reload(Zehavi2005)
Zehavi2005.Table3().getparams(logM1=-14)
# Out:
# Choose logM1 in [14.92 14.6  14.09 13.67 13.42 13.15 12.94 12.77 12.57]
#    Mrmax  logMmin  logM1  alpha     N  chi2_HOD  chi2_powerlaw
# 0  -22.0    13.91  14.92   1.43   7.0     20.74           3.81
# 1  -21.5    13.27  14.60   1.94  10.0      8.81          13.81
# 2  -21.0    12.72  14.09   1.39  11.0      2.18          35.78
# 3  -20.5    12.30  13.67   1.21  11.0     11.65          14.57
# 4  -20.0    12.01  13.42   1.16  11.0      6.09           7.48
# 5  -19.5    11.76  13.15   1.13  11.0     11.70          17.53
# 6  -19.0    11.59  12.94   1.08  11.0      3.87          15.06
# 7  -18.5    11.44  12.77   1.01  11.0     11.94           9.38
# 8  -18.0    11.27  12.57   0.92  11.0     13.33          10.04

# %%
importlib.reload(Zehavi2005)

fig, ax = Zehavi2005.Fig15().full()

logM = np.linspace(11, 15, 25)
params = Zehavi2005.Table3().getparams(Mrmax=-20)
Z05 = Zehavi2005.HOD()

Ncen = Z05.Nc(logM, params['logMmin'])
Nsat = Z05.Ns(10**logM, 10**params['logM1'], params['alpha'])

ax.scatter(10**logM, Ncen, label='Ncen', color='C0', s=10, alpha=0.8)
ax.scatter(10**logM, Nsat, label='Nsat', color='C1', s=10, alpha=0.8)
ax.scatter(10**logM, Ncen+Nsat, label='Ntot', color='C2', s=10, alpha=0.8)
plt.show()
