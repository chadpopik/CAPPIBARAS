# %%
import sys
from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers.Vikram2017 import Vikram2017

# %%
importlib.reload(Vikram2017)

Vikram2017.HaloModel(z=np.array([1]), M200c=10**np.array([5])).c
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 importlib.reload(Vikram2017)
#       2
# ----> 3 Vikram2017.HaloModel(z=np.array([1]), M200c=10**np.array([5])).c
#
# File ~/CAPPIBARAS/Models/Papers/Vikram2017/Vikram2017.py:54, in HaloModel.__init__(self, inputdict, **inputvars)
#      52 for key in ['c', 'R200c', 'dndM', 'b', 'P_lin']:
#      53     if not hasattr(self, key):
# ---> 54         setattr(self, key, getattr(self, f"{key}_func")())
#
# File ~/CAPPIBARAS/Models/Papers/Vikram2017/Vikram2017.py:72, in HaloModel.dndM_func(self)
#      71 def dndM_func(self):
# ---> 72     return self.hmod.dndlogm("sheth99", "fof")
#
# File ~/CAPPIBARAS/Models/Papers/colossus.py:62, in colossus_model.dndlogm(self, MassFunc, MassDef)
#      60 dndlogmfunc = lambda z, M: np.vectorize(mass_function.massFunction)(M, z=z, model=MassFunc, mdef=MassDef, q_out='dndlnM')
#      61 M_h = 10**self.logM*self.cosmology.h
# ---> 62 dlogMfac = (np.log(M_h[1])-np.log(M_h[0]))/(np.log10(M_h[1])-np.log10(M_h[0]))
#      63 return dndlogmfunc(self.z, M_h) *dlogMfac *self.cosmology.h**3 *1/u.Mpc**3/u.dex
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
