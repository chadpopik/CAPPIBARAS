# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# Plot Styling
plt.style.use('dark_background')
plt.rcParams.update({
    'font.family':'serif', 'mathtext.fontset':'dejavuserif',
    'axes.grid':True, 'grid.linestyle': ':', 'grid.alpha': 0.5,
    'xtick.direction':'in', 'xtick.minor.visible': True, 'xtick.top':True,
    'ytick.direction':'in', 'ytick.minor.visible': True, 'ytick.right':True,
})

import sys
sys.path.insert(0, "/global/u2/c/cpopik/CAPPIBARAS")

import importlib
import numpy as np

from Models.PlotChecks.Kou2023 import Kou2023

# %%
importlib.reload(Kou2023)
Kou2023.Table1().df
# Out:
#    Parameter   >10.8   >11.1  >11.25   >11.4
# 0    logMmin  13.470  13.580  13.840  14.200
# 1  sigmalogM   0.760   0.780   0.860   0.959
# 2      logM1  14.119  14.140  14.171  14.100
# 3      betaS   4.380   4.710   5.310   6.350
# 4   1minusbh   0.602   0.623   0.558   0.550
# 5          A   0.981   0.965   0.956   0.961
# 6   alphainc   0.510   0.420   0.390   0.330
# 7    logMinc  13.390  13.420  13.690  13.960
# 8      betaM   4.970   5.910   4.160  10.000
# 9    chi2dof   1.190   1.160   1.512   1.015

# %%
importlib.reload(Kou2023)
fig, ax = Kou2023.Fig4()

# %%
importlib.reload(Kou2023)
fig, ax = Kou2023.Fig6()

# %%
importlib.reload(Kou2023)
fig, ax = Kou2023.Fig8a()
