# %%
import sys, importlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

sys.path.insert(0, "/global/u2/c/cpopik/CAPPIBARAS")

from Models.PlotChecks.Gao2023 import Gao2023

# %%
importlib.reload(Gao2023)

fig, axs = Gao2023.Fig7a()

# %%
importlib.reload(Gao2023)

fig, axs = Gao2023.Fig2()
