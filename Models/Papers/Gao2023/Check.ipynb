# %%
import sys, importlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from Models.Papers.Gao2023 import Gao2023

# %%
importlib.reload(Gao2023)

fig, axs = Gao2023.Fig7a().full()

logMh = np.linspace(10, 15, 30)  # log10(Mh), same convention SHMR() expects
x_plot = logMh - np.log10(Gao2023.Cosmology.h)  # matches Fig7a's log(Mh) [Msun/h] x-axis

colors = {'Auto': 'gold', 'Cross': 'magenta', 'Psat': 'cyan'}

for model, color in colors.items():
    shmr = Gao2023.SHMR(model=model, logMh=logMh)
    axs.plot(x_plot, shmr.log10Mstar(), marker='o', ls='None', color=color, label=model)

axs.legend(fontsize=8)

# %%
importlib.reload(Gao2023)

fig, axs = Gao2023.Fig2().full()
