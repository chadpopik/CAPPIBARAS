# %%
import sys, importlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

sys.path.insert(0, "/global/u2/c/cpopik/CAPPIBARAS")

from Models.PlotChecks.Moser2021 import Moser2021

# %%
importlib.reload(Moser2021)

Moser2021.Table3_bestfit().df
# Out:
#    massselect colorselect    halo      match  log10p0  alphak  betak  Ak2h  \
# 0       mstar         tot    GNFW    matched     3.67    0.64   3.37  1.40
# 1       mstar         red    GNFW    matched     3.28    0.80   3.20  1.37
# 2          mh         tot    GNFW    matched     4.34    0.43   3.44  1.31
# 3          mh         red    GNFW    matched     3.38    0.68   3.30  1.34
# 4       mstar         tot    GNFW  unmatched     4.11    0.49   3.30  1.31
# 5       mstar         red    GNFW  unmatched     3.38    0.68   2.91  1.28
# 6          mh         tot    GNFW  unmatched     5.68    0.30   3.54  1.20
# 7          mh         red    GNFW  unmatched     3.48    0.61   3.03  1.30
# 8       mstar         tot  GNFW1h    matched     6.00    0.17   2.06   NaN
# 9       mstar         red  GNFW1h    matched     6.00    0.16   1.99   NaN
# 10         mh         tot  GNFW1h    matched     6.00    0.17   2.03   NaN
# ...

# %%
importlib.reload(Moser2021)

fig, axs = Moser2021.Fig2()

# %%
importlib.reload(Moser2021)

fig, axs = Moser2021.Fig3()

# %%
importlib.reload(Moser2021)

fig, axs = Moser2021.Fig4row1()

# %%
importlib.reload(Moser2021)

fig, axs = Moser2021.Fig6col1()
