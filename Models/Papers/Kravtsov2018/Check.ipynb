# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers.Kravtsov2018 import Kravtsov2018

# %%
importlib.reload(Kravtsov2018)

Kravtsov2018.Table3().df
# Out:
#   massdef       scatter  log10M1/Msol  log10eps  alpha  delta  gamma
# 0   M200c    no scatter         11.39    -1.618  1.795  4.345  0.619
# 1   M200c  with scatter         11.35    -1.642  1.779  4.394  0.547
# 2   M500c    no scatter         11.32    -1.527  1.856  4.376  0.644
# 3   M500c  with scatter         11.28    -1.556  1.835  4.437  0.567
# 4   M200m    no scatter         11.45    -1.702  1.736  4.273  0.613
# 5   M200m  with scatter         11.41    -1.720  1.727  4.305  0.544
# 6    Mvir    no scatter         11.43    -1.663  1.750  4.290  0.595
# 7    Mvir  with scatter         11.39    -1.685  1.740  4.335  0.531

# %%
importlib.reload(Kravtsov2018)

Kravtsov2018.Table2().df
# Out:
#   Relation  Clusters  slope  normalization  scatter
# 0      BCG       9.0   0.39          12.15     0.21
# 1      sat       9.0   0.87          12.42     0.10
# 2      tot       9.0   0.69          12.63     0.09
# 3      BCG      21.0   0.33          12.24     0.17
# 4      sat      21.0   0.75          12.52     0.10
# 5      tot      21.0   0.59          12.71     0.11

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig4().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig7().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig8().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig9().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig10().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig11().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig12().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig13().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig14().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig14().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig15().full()

# %%
importlib.reload(Kravtsov2018)

fig, axs = Kravtsov2018.Fig16().full()

# %%
importlib.reload(Kravtsov2018)

fig, ax = Kravtsov2018.Fig17().full()

logM200 = np.linspace(9, 15.5, 50)

model = Kravtsov2018.SHMR(logM=)
