# %%
import sys, importlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

sys.path.insert(0, "/global/u2/c/cpopik/CAPPIBARAS")

from Models.PlotChecks.Amodeo2021 import Amodeo2021

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6_row1()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6_row2()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6_row3()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig7()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig11_row2()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig11_row3()
