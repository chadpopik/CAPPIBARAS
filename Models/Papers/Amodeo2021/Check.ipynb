# %%
import sys

from pathlib import Path
root = Path.cwd()
while not (root / "Models").is_dir():
    root = root.parent
sys.path.insert(0, str(root))

from config import *

from Models.Papers.Amodeo2021 import Amodeo2021

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig7().full()

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6().row(0)

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6().row(1)

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig6().row(2)

# %%
(c.c/u.um).to(u.GHz)
# Out:
# <Quantity 299792.458 GHz>

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig11().row(0)

for wavelength, ax in zip([250, 350, 500], axs):
    for data, color in zip(['Hr', 'ACTHr'], ['blue', 'orange']):
        # model = Amodeo2021.Dust(Data=data, wavelength=wavelength*u.um, R=np.linspace(1, 6, 100)*u.arcmin)
        model = Amodeo2021.Dust(Data=data, nu0=(c.c/(wavelength*u.um)).to(u.GHz), R=np.linspace(1, 6, 100)*u.arcmin, wavelength=350*u.um)
        ax.scatter(model.R, model.dustpoly(), color=color, label=data)

# %%
importlib.reload(Amodeo2021)

fig, axs = Amodeo2021.Fig11().row(1)
